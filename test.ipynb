# %%
import whisper

# %%
model = whisper.load_model("base")  #tiny, base, small, medium, large，turbo
result = model.transcribe("data/NHK_news_ja.aac", language="ja")
# Out:
# /Users/fazuo/miniconda3/envs/python3.10.x/lib/python3.10/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")

# %%
result["segments"]
# Out:
# [{'id': 0,
#   'seek': 0,
#   'start': 0.0,
#   'end': 5.0,
#   'text': '競年10月26日に行われた 日本シリーズ第一線を',
#   'tokens': [50364,
#    11957,
#    114,
#    5157,
#    3279,
#    6939,
#    10880,
#    6890,
#    4108,
#    8082,
#    9206,
#    35478,
#    220,
#    27311,
#    11054,
#    12376,
#    3384,
#    29061,
#    18049,
#    31699,
#    5998,
#    50614],
#   'temperature': 0.0,
#   'avg_logprob': -0.32175881914097626,
#   'compression_ratio': 1.3345323741007193,
#   'no_speech_prob': 0.14559222757816315},
#  {'id': 1,
#   'seek': 0,
#   'start': 5.0,
#   'end': 10.0,
#   'text': '民舗が生中経で放送した際 富士TVが同じ時間帯に',
#   'tokens': [50614,
#    16113,
#    10256,
#    245,
#    5142,
#    8244,
#    5975,
#    6948,
#    234,
#    2474,
#    12744,
#    29309,
#    8533,
#    34837,
#    220,
#    47564,
#    30337,
#    12586,
#    5142,
#    13089,
#    9257,
#    20788,
#    4845,
#    107,
#    4108,
#    50864],
#   'temperature': 0.0,
#   'avg_logprob': -0.32175881914097626,
#   'compression_ratio': 1.3345323741007193,
#   'no_speech_prob': 0.14559222757816315},
#  {'id': 2,
#   'seek': 0,
#   'start': 10.0,
#   'end': 15.0,
#   'text': '大多二昇平選手が出場する 大リーグのワールドシリーズの',
#   'tokens': [50864,
#    3582,
#    6392,
#    11217,
#    1431,
#    229,
#    16716,
#    21625,
#    11389,
#    5142,
#    7781,
#    21446,
#    22570,
#    220,
#    3582,
#    12376,
#    3384,
#    23839,
#    2972,
#    39613,
#    35307,
#    11195,
#    11054,
#    12376,
#    3384,
#    29061,
#    2972,
#    51114],
#   'temperature': 0.0,
#   'avg_logprob': -0.32175881914097626,
#   'compression_ratio': 1.3345323741007193,
#   'no_speech_prob': 0.14559222757816315},
#  {'id': 3,
#   'seek': 0,
#   'start': 15.0,
#   'end': 18.0,
#   'text': '大ジェストの放送を行ったことについて',
#   'tokens': [51114,
#    3582,
#    14655,
#    28571,
#    40498,
#    2972,
#    12744,
#    29309,
#    5998,
#    8082,
#    10102,
#    13235,
#    4108,
#    9335,
#    18549,
#    51264],
#   'temperature': 0.0,
#   'avg_logprob': -0.32175881914097626,
#   'compression_ratio': 1.3345323741007193,
#   'no_speech_prob': 0.14559222757816315},
#  {'id': 4,
#   'seek': 0,
#   'start': 18.0,
#   'end': 23.0,
#   'text': 'NPBは 新大関係が一児竜績基存されたとして',
#   'tokens': [51264,
#    45,
#    47,
#    33,
#    3065,
#    220,
#    12560,
#    3582,
#    5196,
#    95,
#    20372,
#    5142,
#    2257,
#    2347,
#    238,
#    11957,
#    250,
#    21030,
#    122,
#    26008,
#    39781,
#    6722,
#    35478,
#    3193,
#    8822,
#    51514],
#   'temperature': 0.0,
#   'avg_logprob': -0.32175881914097626,
#   'compression_ratio': 1.3345323741007193,
#   'no_speech_prob': 0.14559222757816315},
#  {'id': 5,
#   'seek': 0,
#   'start': 23.0,
#   'end': 27.0,
#   'text': '11月3日まで開催された 日本シリーズの',
#   'tokens': [51514,
#    5348,
#    6939,
#    18,
#    6890,
#    28176,
#    8949,
#    161,
#    9915,
#    6722,
#    35478,
#    220,
#    27311,
#    11054,
#    12376,
#    3384,
#    29061,
#    2972,
#    51714],
#   'temperature': 0.0,
#   'avg_logprob': -0.32175881914097626,
#   'compression_ratio': 1.3345323741007193,
#   'no_speech_prob': 0.14559222757816315},
#  {'id': 6,
#   'seek': 2700,
#   'start': 27.0,
#   'end': 31.0,
#   'text': '富士TVの取材パスを募集するなどしました',
#   'tokens': [50364,
#    47564,
#    30337,
#    12586,
#    2972,
#    29436,
#    4422,
#    238,
#    23268,
#    9550,
#    5998,
#    7978,
#    253,
#    26020,
#    22570,
#    3203,
#    7594,
#    44499,
#    50564],
#   'temperature': 0.0,
#   'avg_logprob': -0.22844885445974925,
#   'compression_ratio': 1.4312267657992566,
#   'no_speech_prob': 0.11572189629077911},
#  {'id': 7,
#   'seek': 2700,
#   'start': 31.0,
#   'end': 34.0,
#   'text': 'これについて 構成取引委員会が',
#   'tokens': [50564,
#    9329,
#    4108,
#    9335,
#    18549,
#    220,
#    43362,
#    11336,
#    29436,
#    41301,
#    44230,
#    20992,
#    12949,
#    5142,
#    50714],
#   'temperature': 0.0,
#   'avg_logprob': -0.22844885445974925,
#   'compression_ratio': 1.4312267657992566,
#   'no_speech_prob': 0.11572189629077911},
#  {'id': 8,
#   'seek': 2700,
#   'start': 34.0,
#   'end': 38.0,
#   'text': '富士TVの取材機会が一時的に 奪われ放送覚局の',
#   'tokens': [50714,
#    47564,
#    30337,
#    12586,
#    2972,
#    29436,
#    4422,
#    238,
#    17543,
#    12949,
#    5142,
#    2257,
#    6611,
#    1546,
#    4108,
#    220,
#    1881,
#    103,
#    9206,
#    4132,
#    12744,
#    29309,
#    2888,
#    248,
#    34703,
#    2972,
#    50914],
#   'temperature': 0.0,
#   'avg_logprob': -0.22844885445974925,
#   'compression_ratio': 1.4312267657992566,
#   'no_speech_prob': 0.11572189629077911},
#  {'id': 9,
#   'seek': 2700,
#   'start': 38.0,
#   'end': 42.0,
#   'text': '番組変成の制約につながる恐れがあるとして',
#   'tokens': [50914,
#    33118,
#    30052,
#    40931,
#    11336,
#    2972,
#    25491,
#    30889,
#    4108,
#    9335,
#    3203,
#    5142,
#    4895,
#    47848,
#    4132,
#    5142,
#    24719,
#    3193,
#    8822,
#    51114],
#   'temperature': 0.0,
#   'avg_logprob': -0.22844885445974925,
#   'compression_ratio': 1.4312267657992566,
#   'no_speech_prob': 0.11572189629077911},
#  {'id': 10,
#   'seek': 2700,
#   'start': 42.0,
#   'end': 48.0,
#   'text': 'NPBの調査を行っていることが関係者への 取材で分かりました',
#   'tokens': [51114,
#    45,
#    47,
#    33,
#    2972,
#    32943,
#    17238,
#    119,
#    5998,
#    8082,
#    6102,
#    22979,
#    13235,
#    5142,
#    5196,
#    95,
#    20372,
#    12444,
#    29440,
#    2972,
#    220,
#    29436,
#    4422,
#    238,
#    2474,
#    6627,
#    3703,
#    36941,
#    51414],
#   'temperature': 0.0,
#   'avg_logprob': -0.22844885445974925,
#   'compression_ratio': 1.4312267657992566,
#   'no_speech_prob': 0.11572189629077911},
#  {'id': 11,
#   'seek': 2700,
#   'start': 48.0,
#   'end': 50.0,
#   'text': '関係者によりますと',
#   'tokens': [51414, 5196, 95, 20372, 12444, 4108, 5591, 19420, 3193, 51514],
#   'temperature': 0.0,
#   'avg_logprob': -0.22844885445974925,
#   'compression_ratio': 1.4312267657992566,
#   'no_speech_prob': 0.11572189629077911},
#  {'id': 12,
#   'seek': 2700,
#   'start': 50.0,
#   'end': 53.0,
#   'text': 'NPBと共合する大リーグ機構との取引器を',
#   'tokens': [51514,
#    45,
#    47,
#    33,
#    3193,
#    15408,
#    14245,
#    22570,
#    3582,
#    12376,
#    3384,
#    23839,
#    17543,
#    43362,
#    3193,
#    2972,
#    29436,
#    41301,
#    34386,
#    5998,
#    51664],
#   'temperature': 0.0,
#   'avg_logprob': -0.22844885445974925,
#   'compression_ratio': 1.4312267657992566,
#   'no_speech_prob': 0.11572189629077911},
#  {'id': 13,
#   'seek': 5300,
#   'start': 53.0,
#   'end': 57.0,
#   'text': '行ったことに対する制裁の手段となり',
#   'tokens': [50364,
#    8082,
#    10102,
#    13235,
#    4108,
#    35252,
#    22570,
#    25491,
#    8083,
#    223,
#    2972,
#    11389,
#    28427,
#    3193,
#    3203,
#    5095,
#    50564],
#   'temperature': 0.0,
#   'avg_logprob': -0.1798904834150457,
#   'compression_ratio': 1.4554455445544554,
#   'no_speech_prob': 0.479901522397995},
#  {'id': 14,
#   'seek': 5300,
#   'start': 57.0,
#   'end': 60.0,
#   'text': '大リーグ機構との取引器をためらわせることに',
#   'tokens': [50564,
#    3582,
#    12376,
#    3384,
#    23839,
#    17543,
#    43362,
#    3193,
#    2972,
#    29436,
#    41301,
#    34386,
#    5998,
#    49983,
#    5154,
#    9206,
#    13702,
#    4895,
#    13235,
#    4108,
#    50714],
#   'temperature': 0.0,
#   'avg_logprob': -0.1798904834150457,
#   'compression_ratio': 1.4554455445544554,
#   'no_speech_prob': 0.479901522397995},
#  {'id': 15,
#   'seek': 5300,
#   'start': 60.0,
#   'end': 67.0,
#   'text': 'つながりかねず独善金資本が金じる 取引器の防外などに当たる可能性があるということです',
#   'tokens': [50714,
#    9335,
#    3203,
#    5142,
#    5095,
#    3703,
#    5555,
#    18216,
#    18637,
#    105,
#    5234,
#    226,
#    19117,
#    35380,
#    8802,
#    5142,
#    19117,
#    9257,
#    4895,
#    220,
#    29436,
#    41301,
#    34386,
#    2972,
#    35863,
#    12022,
#    3203,
#    7594,
#    4108,
#    16233,
#    3368,
#    4895,
#    16657,
#    21686,
#    5142,
#    24719,
#    29502,
#    4767,
#    51064],
#   'temperature': 0.0,
#   'avg_logprob': -0.1798904834150457,
#   'compression_ratio': 1.4554455445544554,
#   'no_speech_prob': 0.479901522397995},
#  {'id': 16,
#   'seek': 5300,
#   'start': 67.0,
#   'end': 73.0,
#   'text': '構成取引委員会は調査を進め 今後行政措置を行うかどうか',
#   'tokens': [51064,
#    43362,
#    11336,
#    29436,
#    41301,
#    44230,
#    20992,
#    12949,
#    3065,
#    32943,
#    17238,
#    119,
#    5998,
#    18214,
#    11429,
#    220,
#    6480,
#    5661,
#    8082,
#    18523,
#    6900,
#    103,
#    34719,
#    5998,
#    8082,
#    2646,
#    3703,
#    18395,
#    3703,
#    51364],
#   'temperature': 0.0,
#   'avg_logprob': -0.1798904834150457,
#   'compression_ratio': 1.4554455445544554,
#   'no_speech_prob': 0.479901522397995},
#  {'id': 17,
#   'seek': 5300,
#   'start': 73.0,
#   'end': 76.0,
#   'text': '判断すると見られます',
#   'tokens': [51364,
#    2437,
#    97,
#    4307,
#    255,
#    22570,
#    3193,
#    10470,
#    5154,
#    4132,
#    5368,
#    51514],
#   'temperature': 0.0,
#   'avg_logprob': -0.1798904834150457,
#   'compression_ratio': 1.4554455445544554,
#   'no_speech_prob': 0.479901522397995},
#  {'id': 18,
#   'seek': 5300,
#   'start': 76.0,
#   'end': 82.0,
#   'text': 'NPBは現時点でのコメントは 差し控えさせていただきますとしています',
#   'tokens': [51514,
#    45,
#    47,
#    33,
#    3065,
#    9581,
#    6611,
#    12579,
#    2474,
#    2972,
#    18066,
#    21647,
#    29971,
#    3065,
#    220,
#    21679,
#    2849,
#    48707,
#    6474,
#    6722,
#    47745,
#    32418,
#    22851,
#    3193,
#    8822,
#    11267,
#    51814],
#   'temperature': 0.0,
#   'avg_logprob': -0.1798904834150457,
#   'compression_ratio': 1.4554455445544554,
#   'no_speech_prob': 0.479901522397995}]

# %%
model = whisper.load_model("base")

# load audio and pad/trim it to fit 30 seconds
audio = whisper.load_audio("data/NHK_news_ja.aac")
audio = whisper.pad_or_trim(audio)

# make log-Mel spectrogram and move to the same device as the model
mel = whisper.log_mel_spectrogram(audio, n_mels=model.dims.n_mels).to(model.device)

# detect the spoken language
_, probs = model.detect_language(mel)
print(f"Detected language: {max(probs, key=probs.get)}")

# decode the audio
options = whisper.DecodingOptions()
result = whisper.decode(model, mel, options)

# print the recognized text
print(result.text)
# Out:
# Detected language: ja
# 競年10月26日に行われた 日本シリーズ第一線を民舗が生中経で放送した際 富士TVが同じ時間帯に大多二昇平選手が出場する 大リーグのワールドシリーズの大ジェストの放送を行ったことについてNPBは 新大関係が一児竜績基存されたとして11月3日まで開催された 日本シリーズの

# %%
probs
